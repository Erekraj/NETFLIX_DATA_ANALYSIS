# %% [markdown]
# # NETFLIX DATA ANALYSIS

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
netflix_data = pd.read_csv(r"C:\kaggle Dataset\netflix_data.csv")

# %%
netflix_data
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
netflix_data.keys()
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'duration', 'description', 'genre'],
#       dtype='object')

# %%
netflix_data.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year  duration  \
# 0    August 14, 2020          2020         4
# 1  December 23, 2016          2016        93
# 2  December 20, 2018          2011        78
# 3  November 16, 2017          2009        80
# 4    January 1, 2020          2008       123
#
# ...

# %%
netflix_data.tail()
# Out:
#      show_id     type                                    title     director  \
# 7782   s7783    Movie                                     Zozo  Josef Fares
# 7783   s7784    Movie                                   Zubaan  Mozez Singh
# 7784   s7785    Movie                        Zulu Man in Japan          NaN
# 7785   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    cast         country  \
# 7782  Imad Creidi, Antoinette Turk, Elias Gergi, Car...          Sweden
# 7783  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...           India
# 7784                                            Nasty C             NaN
# 7785                         Adriano Zumbo, Rachel Khoo       Australia
# 7786                                                NaN  United Kingdom
#
#               date_added  release_year  duration  \
# ...

# %%
netflix_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   duration      7787 non-null   int64
#  9   description   7787 non-null   object
#  10  genre         7787 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 669.3+ KB

# %%
netflix_data.describe()
# Out:
#        release_year     duration
# count   7787.000000  7787.000000
# mean    2013.932580    69.122769
# std        8.757395    50.950743
# min     1925.000000     1.000000
# 25%     2013.000000     2.000000
# 50%     2017.000000    88.000000
# 75%     2018.000000   106.000000
# max     2021.000000   312.000000

# %%
netflix_data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# duration           0
# description        0
# genre              0
# dtype: int64

# %%
netflix_data.shape
# Out:
# (7787, 11)

# %%
netflix_data.size
# Out:
# 85657

# %%
netflix_data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# duration         int64
# description     object
# genre           object
# dtype: object

# %% [markdown]
#  # TASK 1 : - IS THERE ANY DUPLICATE RECORD IN THIS DATASTET ? IF YES , THEN REMOVE

# %%
netflix_data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7782    False
# 7783    False
# 7784    False
# 7785    False
# 7786    False
# Length: 7787, dtype: bool

# %%
netflix_data[netflix_data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, duration, description, genre]
# Index: []

# %%
# # to remove duplicate - 

# netflix_data.drop_duplicates()

# %% [markdown]
# # TASK 2 : - IS THERE ANY NULL VALUE

# %%
netflix_data.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False      True  False    False       False
# 1       False  False  False     False  False    False       False
# 2       False  False  False     False  False    False       False
# 3       False  False  False     False  False    False       False
# 4       False  False  False     False  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 7782    False  False  False     False  False    False       False
# 7783    False  False  False     False  False    False       False
# 7784    False  False  False      True  False     True       False
# 7785    False  False  False      True  False    False       False
# 7786    False  False  False     False   True    False       False
#
#       release_year  duration  description  genre
# 0            False     False        False  False
# 1            False     False        False  False
# ...

# %%
netflix_data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# duration           0
# description        0
# genre              0
# dtype: int64

# %%
netflix_data.isnull().sum().sum()
# Out:
# 3624

# %% [markdown]
# # SEABORN LIBRAY (HEAT MAP)

# %%
import seaborn as sns

# %%
sns.heatmap(netflix_data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# # QUE-1 : FOR "HOUSE OF CARDS" WHAT IS THE SHOW ID AND WHO IS DIRECTOR OF THIS SHOW

# %%
netflix_data['title']
# Out:
# 0                                            3%
# 1                                          7:19
# 2                                         23:59
# 3                                             9
# 4                                            21
#                          ...
# 7782                                       Zozo
# 7783                                     Zubaan
# 7784                          Zulu Man in Japan
# 7785                      Zumbo's Just Desserts
# 7786    ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
# Name: title, Length: 7787, dtype: object

# %%
netflix_data[netflix_data['title'].isin(['House of Cards'])]
# Out:
#      show_id     type           title director  \
# 2832   s2833  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#             date_added  release_year  duration  \
# 2832  November 2, 2018          2018         6
#
#                                             description      genre
# 2832  A ruthless politician will stop at nothing to ...  TV Dramas

# %%
netflix_data[netflix_data['title'].str.contains('House of Cards')]
# Out:
#      show_id     type           title director  \
# 2832   s2833  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#             date_added  release_year  duration  \
# 2832  November 2, 2018          2018         6
#
#                                             description      genre
# 2832  A ruthless politician will stop at nothing to ...  TV Dramas

# %%
filtered_data = netflix_data[netflix_data['title'].isin(['House of Cards'])]
filtered_data
# Out:
#      show_id     type           title director  \
# 2832   s2833  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#             date_added  release_year  duration  \
# 2832  November 2, 2018          2018         6
#
#                                             description      genre
# 2832  A ruthless politician will stop at nothing to ...  TV Dramas

# %% [markdown]
# # QUE 2: - IN WHICH YEAR HIGHEST NUMBER OF TV SHOW & MOVIES WERE RELEASED ? SHOW WITH BAR GRAPH

# %%
netflix_data.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year  duration  \
# 0    August 14, 2020          2020         4
# 1  December 23, 2016          2016        93
# 2  December 20, 2018          2011        78
# 3  November 16, 2017          2009        80
# 4    January 1, 2020          2008       123
#
# ...

# %%
netflix_data[netflix_data['type']=='TV Show']
# Out:
# show_id         2410
# type               1
# title           2410
# director         177
# cast            2082
# country           57
# date_added       924
# release_year      46
# duration          15
# description     2408
# genre             17
# dtype: int64

# %%
netflix_data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# duration         int64
# description     object
# genre           object
# dtype: object

# %%
netflix_data['Date_n'] = pd.to_datetime(netflix_data['date_added'],format='mixed',errors='coerce')

# %%
netflix_data.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year  duration  \
# 0    August 14, 2020          2020         4
# 1  December 23, 2016          2016        93
# 2  December 20, 2018          2011        78
# 3  November 16, 2017          2009        80
# 4    January 1, 2020          2008       123
#
# ...

# %%
netflix_data.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added              object
# release_year             int64
# duration                 int64
# description             object
# genre                   object
# Date_n          datetime64[ns]
# dtype: object

# %%
netflix_data['Date_n'].dt.year.value_counts()
# Out:
# Date_n
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: count, dtype: int64

# %%
# IN YEAR 2019 MOST NUMBER OF TV SHOW WAS RELEASED

# %%
netflix_data['Date_n'].dt.year.value_counts().plot(kind='bar',xlabel='Release_Year',ylabel='TV_Show',title='Highest_TV_Show_Rel')
# Out:
# <Axes: title={'center': 'Highest_TV_Show_Rel'}, xlabel='Release_Year', ylabel='TV_Show'>

# %% [markdown]
# # Que 3:- Number of movies  & tv shows in dataset

# %%
netflix_data.groupby('type') # groupby- group all unique item of a column and show their count

# %%
netflix_data.groupby('type').type.count()
# Out:
# type
# Movie      5377
# TV Show    2410
# Name: type, dtype: int64

# %% [markdown]
# COUNTPLOT

# %%
import seaborn as sns

# %%
netflix_data.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year  duration  \
# 0    August 14, 2020          2020         4
# 1  December 23, 2016          2016        93
# 2  December 20, 2018          2011        78
# 3  November 16, 2017          2009        80
# 4    January 1, 2020          2008       123
#
# ...

# %%
netflix_data.groupby('type').type.count().plot(kind='bar',color=['m','r'],xlabel='Type',ylabel='Count',title='Number_of_movies')
# Out:
# <Axes: title={'center': 'Number_of_movies'}, xlabel='Type', ylabel='Count'>

# %%
# QUE :4- SHOWING ALL THE MOVIES THAT WERE RELEASED IN YEAR 2000

# %%
netflix_data.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year  duration  \
# 0    August 14, 2020          2020         4
# 1  December 23, 2016          2016        93
# 2  December 20, 2018          2011        78
# 3  November 16, 2017          2009        80
# 4    January 1, 2020          2008       123
#
# ...

# %%
netflix_data['Year'] = netflix_data['Date_n'].dt.year

# %%
netflix_data.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year  duration  \
# 0    August 14, 2020          2020         4
# 1  December 23, 2016          2016        93
# 2  December 20, 2018          2011        78
# 3  November 16, 2017          2009        80
# 4    January 1, 2020          2008       123
#
# ...

# %%
netflix_data.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added              object
# release_year             int64
# duration                 int64
# description             object
# genre                   object
# Date_n          datetime64[ns]
# Year                   float64
# dtype: object

# %% [markdown]
# FILTERING

# %%
netflix_data[(netflix_data['type'] == 'Movie') & (netflix_data['Year'] == 2000)]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, duration, description, genre, Date_n, Year]
# Index: []

# %%
netflix_data[(netflix_data['type'] == 'Movie') & (netflix_data['Year'] == 2020)]
# Out:
#      show_id   type                                    title  \
# 4         s5  Movie                                       21
# 6         s7  Movie                                      122
# 14       s15  Movie                                     3022
# 27       s28  Movie                                   #Alive
# 28       s29  Movie            #AnneFrank - Parallel Stories
# ...      ...    ...                                      ...
# 7760   s7761  Movie                                Zaki Chan
# 7781   s7782  Movie                                     Zoom
# 7782   s7783  Movie                                     Zozo
# 7784   s7785  Movie                        Zulu Man in Japan
# 7786   s7787  Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# 28    Sabina Fedeli, Anna Migotto
# ...

# %%
netflix_data[(netflix_data['type'] == 'Movie') & (netflix_data['Year'] == 2020)]
# Out:
#      show_id   type                                    title  \
# 4         s5  Movie                                       21
# 6         s7  Movie                                      122
# 14       s15  Movie                                     3022
# 27       s28  Movie                                   #Alive
# 28       s29  Movie            #AnneFrank - Parallel Stories
# ...      ...    ...                                      ...
# 7760   s7761  Movie                                Zaki Chan
# 7781   s7782  Movie                                     Zoom
# 7782   s7783  Movie                                     Zozo
# 7784   s7785  Movie                        Zulu Man in Japan
# 7786   s7787  Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                          director  \
# 4                  Robert Luketic
# 6                 Yasir Al Yasiri
# 14                     John Suits
# 27                         Cho Il
# 28    Sabina Fedeli, Anna Migotto
# ...

# %% [markdown]
# # QUE 5:- SHOW ONLY THE TITLES OF ALL TV SHOW THAT WERE RELEASED OIN INDIA ONLY

# %%
netflix_data[(netflix_data['type'] == 'TV Show') & (netflix_data['country'] == 'India')]
# Out:
#      show_id     type                               title     director  \
# 86       s87  TV Show        21 Sarfarosh: Saragarhi 1897          NaN
# 132     s133  TV Show                           7 (Seven)  Nizar Shafi
# 340     s341  TV Show                        Agent Raghav          NaN
# 364     s365  TV Show                        Akbar Birbal          NaN
# 533     s534  TV Show                 Anjaan: Rural Myths          NaN
# ...      ...      ...                                 ...          ...
# 6398   s6399  TV Show  The Golden Years with Javed Akhtar          NaN
# 6467   s6468  TV Show              The House That Made Me          NaN
# 6520   s6521  TV Show                     The Jungle Book          NaN
# 7292   s7293  TV Show                          Typewriter          NaN
# 7703   s7704  TV Show                     Yeh Meri Family          NaN
#
#                                                    cast country  \
# ...

# %%
netflix_data[(netflix_data['type'] == 'TV Show') & (netflix_data['country'] == 'India')] ['title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6398    The Golden Years with Javed Akhtar
# 6467                The House That Made Me
# 6520                       The Jungle Book
# 7292                            Typewriter
# 7703                       Yeh Meri Family
# Name: title, Length: 73, dtype: object

# %% [markdown]
# # QUE 6: SHOW TOP 10 DIRECTORS WHO GAVE THE HIGHEST NUMBER OF TV SHOW & MOVIES TO NETFLIX

# %%
netflix_data['director'].value_counts().head(10)
# Out:
# director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Youssef Chahine           12
# Martin Scorsese           12
# Jay Chapman               12
# Steven Spielberg          10
# David Dhawan               9
# Ryan Polito                8
# Name: count, dtype: int64

# %%
# Group by director and count their contributions
director_counts = netflix_data.groupby('director').size()



print(director_counts)
# Out:
# director
# A. L. Vijay            2
# A. Raajdheep           1
# A. Salaam              1
# A.R. Murugadoss        2
# Aadish Keluskar        1
#                       ..
# Çagan Irmak            1
# Ísold Uggadóttir       1
# Óskar Thór Axelsson    1
# Ömer Faruk Sorak       2
# Şenol Sönmez           2
# Length: 4049, dtype: int64

# %% [markdown]
# QUE 7:- SHOW ALL THE RECORD WHERE "CATEGORY" IS MOVIE AND TYPE IS "COMEDIES" OR COUNTRY IS "UNUTED KINGDOM"

# %%
netflix_data[(netflix_data['type'] == 'Movie') & (netflix_data['genre'] == 'Comedies') | (netflix_data['country'] == 'United Kingdom')]
# Out:
#      show_id   type                                    title  \
# 18       s19  Movie                                   15-Aug
# 19       s20  Movie                                      '89
# 33       s34  Movie                             #realityhigh
# 34       s35  Movie                                    #Roxy
# 36       s37  Movie                                  #Selfie
# ...      ...    ...                                      ...
# 7762   s7763  Movie                                 Zed Plus
# 7764   s7765  Movie                                     Zero
# 7769   s7770  Movie                 Zindagi Na Milegi Dobara
# 7778   s7779  Movie                               Zombieland
# 7786   s7787  Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                      director  \
# 18         Swapnaneel Jayakar
# 19                        NaN
# 33           Fernando Lebrija
# 34            Michael Kennedy
# 36             Cristina Jacob
# ...                       ...
# ...

# %% [markdown]
# QUE 8:- IN HOW MANY MOVIES/SHOWS, TOM CRUISE WAS CAST ?

# %%
netflix_data[netflix_data['cast'] == 'Tom Cruise']
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, duration, description, genre, Date_n, Year]
# Index: []

# %%
new_data = netflix_data.dropna(subset=['cast'])
new_data
# Out:
#      show_id     type                  title           director  \
# 0         s1  TV Show                     3%                NaN
# 1         s2    Movie                   7:19  Jorge Michel Grau
# 2         s3    Movie                  23:59       Gilbert Chan
# 3         s4    Movie                      9        Shane Acker
# 4         s5    Movie                     21     Robert Luketic
# ...      ...      ...                    ...                ...
# 7781   s7782    Movie                   Zoom       Peter Hewitt
# 7782   s7783    Movie                   Zozo        Josef Fares
# 7783   s7784    Movie                 Zubaan        Mozez Singh
# 7784   s7785    Movie      Zulu Man in Japan                NaN
# 7785   s7786  TV Show  Zumbo's Just Desserts                NaN
#
#                                                    cast        country  \
# 0     João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# ...

# %%
new_data[new_data['cast'].str.contains("Tom Cruise")]
# Out:
#      show_id   type     title              director  \
# 3860   s3861  Movie  Magnolia  Paul Thomas Anderson
# 5070   s5071  Movie  Rain Man        Barry Levinson
#
#                                                    cast        country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5070  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#            date_added  release_year  duration  \
# 3860  January 1, 2020          1999       189
# 5070     July 1, 2019          1988       134
#
#                                             description           genre  \
# 3860  Through chance, human action, past history and...          Dramas
# 5070  A fast-talking yuppie is forced to slow down w...  Classic Movies
#
#          Date_n    Year
# 3860 2020-01-01  2020.0
# 5070 2019-07-01  2019.0

# %%
netflix_data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# duration           0
# description        0
# genre              0
# Date_n            10
# Year              10
# dtype: int64

# %%
new_data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2090
# cast               0
# country          411
# date_added        10
# release_year       0
# duration           0
# description        0
# genre              0
# Date_n            10
# Year              10
# dtype: int64

# %%
# QUE: 9 - DIFFERENT RATING PROVIDED BY NETFLIX

# %%
rating_data = pd.read_csv(r"C:\kaggle Dataset\Netflix_Dataset_Rating.csv")
rating_data.head()
# Out:
#    User_ID  Rating  Movie_ID
# 0   712664       5         3
# 1  1331154       4         3
# 2  2632461       3         3
# 3    44937       5         3
# 4   656399       4         3

# %%
rating_data['Rating'].nunique()
# Out:
# 5

# %%
rating_data.Rating.unique()
# Out:
# array([5, 4, 3, 1, 2], dtype=int64)

# %%
# HOW MANY MOVIES GOT THE 'TV-14' RATING IN CANANDA ?

# %%
# MAXIMUM DURATION OF A MOVIE

# %%
netflix_data['duration'].unique()
# Out:
# array([  4,  93,  78,  80, 123,   1,  95, 119, 118, 143, 103,  89,  91,
#        149, 144, 124,  87, 110, 128, 117, 100,   2,  84,  99,  90, 102,
#        104, 105,  56, 125,  81,  97, 106, 107, 109,  44,  75, 101,   3,
#         37, 113, 114, 130,  94, 140, 135,  82,  70, 121,  92, 164,  53,
#         83, 116,  86, 120,  96, 126, 129,  77, 137, 148,  28, 122, 176,
#         85,  22,  68, 111,  29, 142, 168,  21,  59,  20,  98, 108,  76,
#         26, 156,  30,  57, 150, 133, 115, 154, 127, 146, 136,  88, 131,
#         24, 112,  74,  63,  38,  25, 174,  60, 153, 158, 151, 162,  54,
#         51,  69,  64, 147,  42,  79,   5,  40,  45, 172,  10, 163,   9,
#         55,  72,  61,  71, 160, 171,  48, 139, 157,  15,  65, 134, 161,
#         62,   8, 186,  49,  73,  58, 165, 166, 138, 159, 141, 132,  52,
#         67,  34,  66, 312, 180,  47,   6, 155,  14, 177,  11,  46, 145,
#          7,  13,  12,  43,  50,  23, 185, 200, 169,  27, 170, 196,  33,
# ...

# %%
netflix_data.duration.unique()
# Out:
# array([  4,  93,  78,  80, 123,   1,  95, 119, 118, 143, 103,  89,  91,
#        149, 144, 124,  87, 110, 128, 117, 100,   2,  84,  99,  90, 102,
#        104, 105,  56, 125,  81,  97, 106, 107, 109,  44,  75, 101,   3,
#         37, 113, 114, 130,  94, 140, 135,  82,  70, 121,  92, 164,  53,
#         83, 116,  86, 120,  96, 126, 129,  77, 137, 148,  28, 122, 176,
#         85,  22,  68, 111,  29, 142, 168,  21,  59,  20,  98, 108,  76,
#         26, 156,  30,  57, 150, 133, 115, 154, 127, 146, 136,  88, 131,
#         24, 112,  74,  63,  38,  25, 174,  60, 153, 158, 151, 162,  54,
#         51,  69,  64, 147,  42,  79,   5,  40,  45, 172,  10, 163,   9,
#         55,  72,  61,  71, 160, 171,  48, 139, 157,  15,  65, 134, 161,
#         62,   8, 186,  49,  73,  58, 165, 166, 138, 159, 141, 132,  52,
#         67,  34,  66, 312, 180,  47,   6, 155,  14, 177,  11,  46, 145,
#          7,  13,  12,  43,  50,  23, 185, 200, 169,  27, 170, 196,  33,
# ...

# %%
netflix_data.duration.max()
# Out:
# 312

# %%
netflix_data.duration.min()
# Out:
# 1

# %%
# Que 11:- Which individual country has the highest number of TV shows ?a

# %%
tv_show = netflix_data[(netflix_data['type']=='TV Show')]

# %%
tv_show.head(2)
# Out:
#   show_id     type title     director  \
# 0      s1  TV Show    3%          NaN
# 5      s6  TV Show    46  Serdar Akar
#
#                                                 cast country       date_added  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...  Turkey     July 1, 2017
#
#    release_year  duration                                        description  \
# 0          2020         4  In a future where the elite inhabit an island ...
# 5          2016         1  A genetics professor experiments with a treatm...
#
#               genre     Date_n    Year
# 0  International TV 2020-08-14  2020.0
# 5  International TV 2017-07-01  2017.0

# %%
tv_show.country.value_counts()
# Out:
# country
# United States     783
# United Kingdom    236
# Japan             162
# South Korea       152
# Canada             84
# India              73
# Taiwan             70
# France             59
# Australia          52
# Spain              49
# Mexico             44
# China              38
# Turkey             28
# Brazil             27
# Germany            24
# Colombia           23
# Thailand           22
# Singapore          18
# Argentina          18
# Italy              17
# Russia             15
# Egypt              12
# Denmark            11
# Norway              9
# Belgium             8
# Nigeria             8
# Israel              7
# Malaysia            7
# Poland              7
# Sweden              7
# Lebanon             6
# Ireland             6
# South Africa        5
# Netherlands         5
# Pakistan            4
# Chile               4
# Saudi Arabia        4
# Hong Kong           3
# Finland             3
# Indonesia           2
# Ukraine             2
# ...

# %%
(tv_show.country.value_counts()).max()
# Out:
# 783

# %%
tv_show.country.value_counts().head(1)
# Out:
# country
# United States    783
# Name: count, dtype: int64

# %% [markdown]
# # SORTING THE DATASET BY YEAR

# %%
netflix_data.sort_values(by='Year',ascending=False)
# Out:
#      show_id     type                         title  \
# 7351   s7352    Movie                       Unknown
# 2013   s2014    Movie              Enter the Dragon
# 2349   s2350    Movie                     Gangaajal
# 1194   s1195    Movie             Can't Hardly Wait
# 1497   s1498    Movie                Cool Hand Luke
# ...      ...      ...                           ...
# 3374   s3375  TV Show                      Kikoriki
# 3492   s3493  TV Show           La Familia P. Luche
# 3946   s3947  TV Show                         Maron
# 5137   s5138  TV Show                  Red vs. Blue
# 6065   s6066  TV Show  The Adventures of Figaro Pho
#
#                           director  \
# 7351            Jaume Collet-Serra
# 2013                 Robert Clouse
# 2349                   Prakash Jha
# 1194  Harry Elfont, Deborah Kaplan
# 1497              Stuart Rosenberg
# ...                            ...
# 3374                           NaN
# 3492                           NaN
# ...

# %%
# Que 13:- Category is Movie and Type is 'dramas'

# %%
netflix_data[(netflix_data['type'] == 'Movie') & (netflix_data['genre'] == 'Dramas')]
# Out:
#      show_id   type                     title           director  \
# 1         s2  Movie                      7:19  Jorge Michel Grau
# 4         s5  Movie                        21     Robert Luketic
# 7         s8  Movie                       187     Kevin Reynolds
# 10       s11  Movie                      1922       Zak Hilditch
# 15       s16  Movie                    Oct-01     Kunle Afolayan
# ...      ...    ...                       ...                ...
# 7768   s7769  Movie  Zindagi Kitni Haseen Hay      Anjum Shahzad
# 7770   s7771  Movie                   Zinzana    Majid Al Ansari
# 7780   s7781  Movie                       Zoo       Shlok Sharma
# 7782   s7783  Movie                      Zozo        Josef Fares
# 7783   s7784  Movie                    Zubaan        Mozez Singh
#
#                                                    cast        country  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# ...

# %%
netflix_data[(netflix_data['type'] == 'TV Show') & (netflix_data['genre'] == 'Kids')]
# Out:
#      show_id     type                           title     director  \
# 108     s109  TV Show        3Below: Tales of Arcadia          NaN
# 111     s112  TV Show                         44 Cats          NaN
# 225     s226  TV Show  A Series of Unfortunate Events          NaN
# 276     s277  TV Show                    Abby Hatcher  Kyran Kelly
# 364     s365  TV Show                    Akbar Birbal          NaN
# ...      ...      ...                             ...          ...
# 7730   s7731  TV Show                    You vs. Wild          NaN
# 7756   s7757  TV Show                              Z4          NaN
# 7759   s7760  TV Show                       Zak Storm          NaN
# 7766   s7767  TV Show                    Zig & Sharko          NaN
# 7777   s7778  TV Show                     Zombie Dumb          NaN
#
#                                                    cast        country  \
# 108   Tatiana Maslany, Diego Luna, Nick Offerman, Ni...  United States
# ...
